# %%
t = (1,2,3)

# %%
mylist = [1,2,3]

# %%
type(t)
# Out:
# tuple

# %%
type(mylist)
# Out:
# list

# %%
t
# Out:
# (1, 2, 3)

# %%
t = ('one',2)

# %%
t
# Out:
# ('one', 2)

# %%
t[0]
# Out:
# 'one'

# %%
t[-1]
# Out:
# 2

# %%
t =('a','a','b')

# %%
t.count('a') #liczy ile razy podany element jet w typ tuplecie
# Out:
# 2

# %%
t.index('a') #wywietla w jakim indeksie jest dany elemet ale tylko pierwszy elemt
# Out:
# 0

# %%
mylist
# Out:
# [1, 2, 3]

# %%
mylist [0] = 'wypierdalaj'

# %%
mylist
# Out:
# ['wypierdalaj', 2, 3]

# %%
t[0] = 5 # nie da sie zmienic jego elementu, przydatne aby nie zminic elemntow i utrzymac integracje danych
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-6dd06f73cec4> in <module>
# ----> 1 t[0] = 5
#
# TypeError: 'tuple' object does not support item assignment
